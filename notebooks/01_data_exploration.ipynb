# %%
import pandas as pd

climate = pd.read_csv(r"C:\Users\parve\Music\data\raw\climate_change_dataset.csv")
air = pd.read_csv(r"C:\Users\parve\Music\data\raw\global_environment_air_pollution_dataset.csv")
deforestation = pd.read_csv(r"C:\Users\parve\Music\data\raw\global_deforestation_2000_2025.csv")

for name, df in [("Climate", climate), ("Air", air), ("Deforestation", deforestation)]:
    print(f"\n{'='*50}\n{name}")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(f"Nulls:\n{df.isnull().sum().to_string()}")
    print(f"Dtypes:\n{df.dtypes.to_string()}")
# Out:
# ...
# Climate
# Shape: (1000, 10)
# Columns: ['Year', 'Country', 'Avg Temperature (°C)', 'CO2 Emissions (Tons/Capita)', 'Sea Level Rise (mm)', 'Rainfall (mm)', 'Population', 'Renewable Energy (%)', 'Extreme Weather Events', 'Forest Area (%)']
# Nulls:
# Year                           0
# Country                        0
# Avg Temperature (°C)           0
# CO2 Emissions (Tons/Capita)    0
# Sea Level Rise (mm)            0
# Rainfall (mm)                  0
# Population                     0
# Renewable Energy (%)           0
# Extreme Weather Events         0
# Forest Area (%)                0
# Dtypes:
# Year                             int64
# Country                            str
# Avg Temperature (°C)           float64
# CO2 Emissions (Tons/Capita)    float64
# Sea Level Rise (mm)            float64
# Rainfall (mm)                    int64
# Population                       int64
# Renewable Energy (%)           float64
# Extreme Weather Events           int64
# ...
